# %% [markdown]
# # Tutorial2:cell-type annotation on scST data (without pre-annoated info)

# %% [markdown]
# We utilized MERFISH mouse hypothalamic data (ID=1) to test the annotation accuracy of STAMapper. The scRNA-seq dataset and the scST dataset can be download from [Google Drive](https://drive.google.com/drive/folders/1xP3Fh94AwKu4OsH3khGq-KEw0VCoiRnL) (MERFISH_hypothalamic.zip).

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import scanpy as sc
import os
import shutil
from STAMapper import pipeline, pp, pl
import warnings
warnings.filterwarnings("ignore")

# %%
key_class1 = 'celltype'#celltype label for adata_sc, stored in adata_sc.obs[key_class1]
key_class2 = None#set None for the key_class2 of spatial data if it is not annotated
key_classes = [key_class1, key_class2]

# %% [markdown]
# ## Load data

# %%
adata_sc = sc.read_h5ad(r'../data/hypothalamic_sc.h5ad')
adata_sp = sc.read_h5ad(r'../data/MERFISH_hypothalamic_1.h5ad') 

sc_name = 'hypothalamic_sc'
sp_name = 'hypothalamic_MERFISH_not_use_manual_annotation'

#change dsnames for a new training task
dsnames = (sc_name, sp_name)

#delete dirs for old task with the same dsnames
if os.path.exists(Path(".") /'_temp' / f'{dsnames}'):
    shutil.rmtree(Path(".") /'_temp' / f'{dsnames}')

# %% [markdown]
# ### Optional (filter low-quality genes and cells)

# %% [markdown]
# Make sure genes are set as var_index in adata_sc and adata_sp, otherwise you can use:

# %%
#adata_sc.var.set_index('gene_name', inplace = True)

# %% [markdown]
# The filtering process is not used in this case (since they have been filtered in advance), but may be useful for other data.

# %%
#sc.pp.filter_cells(adata_sc, min_genes=100)
#sc.pp.filter_genes(adata_sc, min_cells=3)

#sc.pp.filter_cells(adata_sp, min_genes=100)
#sc.pp.filter_genes(adata_sp, min_cells=3)

# %% [markdown]
# ## Training

# %%
adatas = [adata_sc, adata_sp]
outputs = pipeline.training(adatas=adatas, dsnames=dsnames, key_classes=key_classes)
# Out:
# Data Preprocessing!
# [leiden] Time used:  162.9165 s
# a new directory made:
# 	_temp\('hypothalamic_sc', 'hypothalamic_MERFISH_not_use_manual_annotation')\0\figs
# already exists:
# 	_temp\('hypothalamic_sc', 'hypothalamic_MERFISH_not_use_manual_annotation')\0
# [*] Setting dataset names:
# 	0-->hypothalamic_sc
# 	1-->hypothalamic_MERFISH_not_use_manual_annotation
# [*] Setting aligned features for observation nodes (self._features)
# [*] Setting observation-by-variable adjacent matrices (`self._ov_adjs`) for making merged graph adjacent matrix of observation and variable nodes
# -------------------- Summary of the DGL-Heterograph --------------------
# Graph(num_nodes={'cell': 94743, 'gene': 153},
#       num_edges={('cell', 'express', 'gene'): 4479163, ('cell', 'self_loop_cell', 'cell'): 94743, ('cell', 'similar_to', 'cell'): 631726, ('gene', 'expressed_by', 'cell'): 4479163, ('gene', 'self_loop_gene', 'gene'): 153},
#       metagraph=[('cell', 'gene', 'express'), ('cell', 'cell', 'self_loop_cell'), ('cell', 'cell', 'similar_to'), ('gene', 'cell', 'expressed_by'), ('gene', 'gene', 'self_loop_gene')])
# self-loops for observation-nodes: True
# self-loops for variable-nodes: True
#
# AlignedDataPair with 94743 obs- and 153 var-nodes
# n_obs1 (hypothalamic_sc): 30370
# n_obs2 (hypothalamic_MERFISH_not_use_manual_annotation): 64373
# Dimensions of the obs-node-features: 153
# main directory: _temp\('hypothalamic_sc', 'hypothalamic_MERFISH_not_use_manual_annotation')\0
# model directory: _temp\('hypothalamic_sc', 'hypothalamic_MERFISH_not_use_manual_annotation')\0\_models
# ============== start training (device='cuda') ==============
# Epoch 0000 | Train Acc: 0.4373 | Test: 0.0000 (max=0.0000) | AMI=0.0307 | Time: 3.1560
# Epoch 0050 | Train Acc: 0.9645 | Test: 0.0000 (max=0.0000) | AMI=0.6676 | Time: 1.5084
# [current best] model weights backup
# Epoch 0099 | Train Acc: 0.9792 | Test: 0.0000 (max=0.0000) | AMI=0.7099 | Time: 1.4958
# Epoch 0100 | Train Acc: 0.9814 | Test: 0.0000 (max=0.0000) | AMI=0.7018 | Time: 1.4955
# [current best] model weights backup
# Epoch 0101 | Train Acc: 0.9831 | Test: 0.0000 (max=0.0000) | AMI=0.7174 | Time: 1.4951
# [current best] model weights backup
# Epoch 0103 | Train Acc: 0.9819 | Test: 0.0000 (max=0.0000) | AMI=0.7234 | Time: 1.4966
# [current best] model weights backup
# Epoch 0105 | Train Acc: 0.9822 | Test: 0.0000 (max=0.0000) | AMI=0.7272 | Time: 1.4962
# [current best] model weights backup
# Epoch 0116 | Train Acc: 0.9843 | Test: 0.0000 (max=0.0000) | AMI=0.7275 | Time: 1.4952
# [current best] model weights backup
# Epoch 0118 | Train Acc: 0.9848 | Test: 0.0000 (max=0.0000) | AMI=0.7296 | Time: 1.4951
# [current best] model weights backup
# Epoch 0143 | Train Acc: 0.9888 | Test: 0.0000 (max=0.0000) | AMI=0.7300 | Time: 1.4934
# Epoch 0150 | Train Acc: 0.9877 | Test: 0.0000 (max=0.0000) | AMI=0.7255 | Time: 1.4933
# [current best] model weights backup
# Epoch 0186 | Train Acc: 0.9916 | Test: 0.0000 (max=0.0000) | AMI=0.7314 | Time: 1.4916
# [current best] model weights backup
# Epoch 0194 | Train Acc: 0.9907 | Test: 0.0000 (max=0.0000) | AMI=0.7317 | Time: 1.4914
# [current best] model weights backup
# Epoch 0198 | Train Acc: 0.9911 | Test: 0.0000 (max=0.0000) | AMI=0.7322 | Time: 1.4912
# Epoch 0200 | Train Acc: 0.9911 | Test: 0.0000 (max=0.0000) | AMI=0.7195 | Time: 1.4909
# [current best] model weights backup
# Epoch 0201 | Train Acc: 0.9897 | Test: 0.0000 (max=0.0000) | AMI=0.7328 | Time: 1.4907
# [current best] model weights backup
# Epoch 0203 | Train Acc: 0.9913 | Test: 0.0000 (max=0.0000) | AMI=0.7356 | Time: 1.4905
# [current best] model weights backup
# Epoch 0240 | Train Acc: 0.9905 | Test: 0.0000 (max=0.0000) | AMI=0.7393 | Time: 1.4894
# Epoch 0250 | Train Acc: 0.9919 | Test: 0.0000 (max=0.0000) | AMI=0.7332 | Time: 1.4891
# [current best] model weights backup
# Epoch 0270 | Train Acc: 0.9924 | Test: 0.0000 (max=0.0000) | AMI=0.7402 | Time: 1.4877
# Epoch 0300 | Train Acc: 0.9916 | Test: 0.0000 (max=0.0000) | AMI=0.7191 | Time: 1.4871
# [current best] model weights backup
# Epoch 0301 | Train Acc: 0.9914 | Test: 0.0000 (max=0.0000) | AMI=0.7410 | Time: 1.4871
# Epoch 0350 | Train Acc: 0.9913 | Test: 0.0000 (max=0.0000) | AMI=0.7259 | Time: 1.4875
# Epoch 0400 | Train Acc: 0.9920 | Test: 0.0000 (max=0.0000) | AMI=0.7362 | Time: 1.4878
# Epoch 0450 | Train Acc: 0.9933 | Test: 0.0000 (max=0.0000) | AMI=0.7265 | Time: 1.4957
# Epoch 0500 | Train Acc: 0.9926 | Test: 0.0000 (max=0.0000) | AMI=0.7337 | Time: 1.5009
# The AMI didn't increase for the last 100 epohs, early stopping!
# Epoch 0501 | Train Acc: 0.9929 | Test: 0.0000 (max=0.0000) | AMI=0.7309 | Time: 1.5009
# figure has been saved into:
# 	_temp\('hypothalamic_sc', 'hypothalamic_MERFISH_not_use_manual_annotation')\0\figs\cluster_index.png
# states loaded from: _temp\('hypothalamic_sc', 'hypothalamic_MERFISH_not_use_manual_annotation')\0\_models\weights_epoch301.pt
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 17.75it/s]
# WARNING:root:An error occurred when plotting results: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# object saved into:
# 	 _temp\('hypothalamic_sc', 'hypothalamic_MERFISH_not_use_manual_annotation')\0\datapair_init.pickle

# %% [markdown]
# ## Check accuracy

# %%
folder_path = Path(".") /'_temp' / f'{dsnames}'
best_model, accuracy, macrof1, weightedf1 = pp.calc_scores(folder_path, key_class2)
print(f"Best Model: {best_model}, Accuracy: {accuracy:.3f}, Macro F1 Score: {macrof1:.3f}, Weighted F1 Score: {weightedf1:.3f}")
# Out:
# Best Model: 0, Accuracy: 0.000, Macro F1 Score: 0.000, Weighted F1 Score: 0.000

# %% [markdown]
#  ## Visualization

# %%
obs = pd.read_csv(folder_path/f'{best_model}'/'obs.csv',index_col=0)
obs = obs[obs['dataset'].isin([sp_name])]
adata_sp.obs['predicted'] = list(obs['predicted'])

# %%
sc.pp.normalize_total(adata_sp, target_sum=1e4)
sc.pp.log1p(adata_sp)
#sc.pp.scale(adata_sp, max_value=10)#optional
sc.tl.pca(adata_sp, svd_solver="arpack")
sc.pp.neighbors(adata_sp, n_neighbors=10, n_pcs=40)
sc.tl.umap(adata_sp)

# %% [markdown]
# Compare maunal annotation(upper panel) with predicted (lower panel).

# %%
palette = {'Astrocytes': '#1f77b4',
 'Inhibitory': '#9467bd',
 'Endothelial': '#ff7f0e',
 'Ependymal': '#2ca02c',
 'Excitatory': '#d62728',
 'Fibroblast': '#f3bb70',
 'Macrophage': '#e7ac18',
 'Microglia': '#8c564b',
 'Mural': '#bcbd22',
 'OD Immature': '#aec7e8',
 'OD Mature': '#7f7f7f',
 'OD Newly formed': '#fda1a0'}

sc.pl.umap(adata_sp, color=["predicted"], ncols=1, palette=palette)
